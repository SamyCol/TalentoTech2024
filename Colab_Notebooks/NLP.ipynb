# %%
import nltk
import random
nltk.download()
from nltk.tokenize import word_tokenize
sentence="NLTK es una herramienta .........."
tokens=word_tokenize(sentence)
print(tokens)
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-c3383b2d2cda> in <cell line: 3>()
#       1 import nltk
#       2 import random
# ----> 3 nltk.download()
#       4 from nltk.tokenize import word_tokenize
#       5 sentence="NLTK es una herramienta .........."
#
# /usr/local/lib/python3.10/dist-packages/nltk/downloader.py in download(self, info_or_id, download_dir, quiet, force, prefix, halt_on_error, raise_on_error, print_error_to)
#     761             if download_dir is not None:
#     762                 self._download_dir = download_dir
# --> 763             self._interactive_download()
# ...

# %%
from nltk.stem import PorterStemmer
words=["running","gaming","plays","jumped"]
stemmer=PorterStemmer()
stems=[stemmer.stem(word) for word in words]
print(stems)
# Out:
# ['run', 'game', 'play', 'jump']

# %%
import nltk
nltk.download('punkt') # Download the 'punkt' resource for tokenization.
from nltk import pos_tag
from nltk.tokenize import word_tokenize

sentence="NLTK es una biblioteeca de procesamientos...."
tokens=word_tokenize(sentence)
tagged_words=pos_tag(tokens)
print(tagged_words)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [('NLTK', 'NNP'), ('es', 'CC'), ('una', 'JJ'), ('biblioteeca', 'NN'), ('de', 'IN'), ('procesamientos', 'NNS'), ('....', 'VBP')]

# %%
data=[
    ("i love this movie", "positive"),
    ("i hate this movie", "negative"),
    ("this movie is good", "positive"),
    ("this movie is bad", "negative"),
    ("this movie is not bad", "positive"),
    ("this movie is not good", "negative"),
    ("I can´t standwatching this movie", "negative"),
    ("this movie is terrible", "negative"),
    ("this movie is great", "positive"),
    ("I don´t like thsi movie", "negative")
]
