# %%
from tensorflow import keras

tensorflow.keras.datasets.fashion_mnist.load_data()
fashion_mnist = keras.datasets.fashion_mnist  # Carga el conjunto de datos fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()  # Carga los datos de entrenamiento y prueba

# Carga el conjunto de datos fashion_mnist
(x_train, y_train), (x_test, y_test) = keras.datasets.fashion_mnist.load_data()

# Normaliza los valores de píxeles a un rango de 0 a 1
x_train = x_train / 255.0
x_test = x_test / 255.0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b618469621a7> in <cell line: 3>()
#       1 from tensorflow import keras
#       2
# ----> 3 tensorflow.keras.datasets.fashion_mnist.load_data()
#       4 fashion_mnist = keras.datasets.fashion_mnist  # Carga el conjunto de datos fashion_mnist
#       5 (train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()  # Carga los datos de entrenamiento y prueba
#
# NameError: name 'tensorflow' is not defined

# %%
(train_images_fm, train_labels_fm), (test_images_fm, test_labels_fm) = (fashion_mnist.load_data())
(train_images_fm, train_labels_fm), (test_images_fm, test_labels_fm)
train_images_fm = train_images_fm / 255.0
test_images_fm = test_images_fm / 255.0
train_images_fm
train_labels_fm
test_images_fm
test_labels_fm
model_fm
