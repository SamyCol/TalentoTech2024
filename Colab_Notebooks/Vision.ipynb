# %%
import numpy as np # Importing the numpy library with the alias 'np'
import cv2
from google.colab.patches import cv2_imshow # Import cv2_imshow for displaying images in Colab

img=np.ones((400,600,3), 'uint8')
img[0:400,0:300]=[255,0,255]
img[0:400,300:600]=[0,255,0]
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=600x400>

# %%
img[190:210,0:600]=[0,255,255]
img[0:400,290:310]=[0,255,255]
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=600x400>

# %%
img[0:400,0:20]=[255,0,0]
img[0:20,0:600]=[255,0,0]
img[0:400,580:600]=[255,0,0]
img[380:400,0:600]=[255,0,0]
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=600x400>

# %%
import numpy as np
import cv2 # Import the cv2 library
from matplotlib import pyplot as plt
from google.colab.patches import cv2_imshow

new_image1 = cv2.imread('/content/1.jpg')
cv2_imshow(new_image1)
new_image2 = cv2.imread('/content/2.jpg')
cv2_imshow(new_image2)
