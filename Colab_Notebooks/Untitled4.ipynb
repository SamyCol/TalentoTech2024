# %% [markdown]
# # EJERCICIO DE DATAFRAME

# %%
import pandas as pd

# Leer el archivo CSV y convertirlo en un DataFrame
df = pd.read_csv('fraude.csv')

# Para chequqear muestra las primeras 5 filas para asegurarse de que se ha cargado correctamente
print("Primeras 5 filas del DataFrame:")
print(df.head())

# Obtener un resumen estadístico básico de las columnas numéricas
print(df.describe())

# Información sobre el DataFrame (columnas, tipos de datos, valores nulos, etc.)
print(df.info())

# Mostrar el tamaño del DataFrame (número de filas y columnas)
print(df.shape)
df
# Out:
# Primeras 5 filas del DataFrame:
#    step       customer  age gender zipcodeOri       merchant zipMerchant  \
# 0     0  'C1093826151'  '4'    'M'    '28007'   'M348934600'     '28007'
# 1     0   'C352968107'  '2'    'M'    '28007'   'M348934600'     '28007'
# 2     0  'C2054744914'  '4'    'F'    '28007'  'M1823072687'     '28007'
# 3     0  'C1760612790'  '3'    'M'    '28007'   'M348934600'     '28007'
# 4     0   'C757503768'  '5'    'M'    '28007'   'M348934600'     '28007'
#
#               category  amount  fraud
# 0  'es_transportation'    4.55      0
# 1  'es_transportation'   39.68      0
# 2  'es_transportation'   26.89      0
# 3  'es_transportation'   17.25      0
# 4  'es_transportation'   35.72      0
#                 step         amount          fraud
# count  594643.000000  594643.000000  594643.000000
# mean       94.986827      37.890135       0.012108
# std        51.053632     111.402831       0.109369
# min         0.000000       0.000000       0.000000
# ...
