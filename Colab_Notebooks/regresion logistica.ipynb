# %%
from os.path import defpath
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
def = [(diabetis.csv)]
from sklearn.linear_model import LogisticRegression
sklearn_model = LogisticRegression(random_state=0, solver='lbfgs',multi_class='multinomial').fit(X_train, y_train)
