# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris
from sklearn.cluster import DBSCAN
import matplotlib.pyplot as plt

# Load the Iris dataset
iris = load_iris()
X = iris.data
X

# Perform DBSCAN clustering
dbscan = DBSCAN(eps=0.5, min_samples=5)
clusters = dbscan.fit_predict(X)

# Adiciona la etiqueta cluster al dataset
iris_df = pd.DataFrame(iris.data, columns=iris.feature_names)
iris_df['cluster'] = clusters
iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      cluster
# 0          0
# ...

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler


# Seleccionar las columnas que quieres escalar (features)
features = ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
X = iris_df[features]

# Crea un objeto StandardScaler
scaler = StandardScaler()

# Ajusta el scaler a tus datos y transforma las features
X_scaled = scaler.fit_transform(X)

# Crea un nuevo DataFrame con las features escaladas y la columna 'cluster'
scaled_iris_df = pd.DataFrame(X_scaled, columns=features, index=iris_df.index)
scaled_iris_df['cluster'] = iris_df['cluster']

# Ahora 'scaled_iris_df' contiene tus datos escalados
# Puedes usar este DataFrame para visualizar o entrenar modelos.

# Ejemplo de visualización con los datos escalados:
from matplotlib import pyplot as plt

scaled_iris_df.plot(kind='scatter', x='sepal length (cm)', y='petal length (cm)', c='cluster', colormap='viridis')
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.title('DBSCAN Clustering of Iris Dataset (Scaled Data)') # Añade un título
plt.show()

# %%
# Visualize the clusters
plt.scatter(iris_df['sepal length (cm)'], iris_df['sepal width (cm)'], c=iris_df['cluster'])
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.title('DBSCAN Clustering of Iris Dataset')
plt.show()

# %%
from matplotlib import pyplot as plt

iris_df.plot(kind='scatter', x='sepal length (cm)', y='petal length (cm)', c='cluster', colormap='viridis')
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.show()

# %%
# Visualize the clusters
plt.scatter(iris_df['sepal length (cm)'], iris_df['cluster'], c=iris_df['cluster'])
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.title('DBSCAN Clustering of Iris Dataset')
plt.show()

# %%
cluster0 = iris_df[iris_df["cluster"] == 0]
cluster1 = iris_df[iris_df["cluster"] == 1]
cluster2 = iris_df[iris_df["cluster"] == 2]
cluster3 = iris_df[iris_df["cluster"] == 3]
cluster4 = iris_df[iris_df["cluster"] == 4]
cluster0
cluster1
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 50                 7.0               3.2                4.7               1.4
# 51                 6.4               3.2                4.5               1.5
# 52                 6.9               3.1                4.9               1.5
# 53                 5.5               2.3                4.0               1.3
# 54                 6.5               2.8                4.6               1.5
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      cluster
# 50         1
# ...

# %%
cluster2
# Out:
# Empty DataFrame
# Columns: [sepal length (cm), sepal width (cm), petal length (cm), petal width (cm), cluster]
# Index: []

# %%
cluster2
# Out:
# Empty DataFrame
# Columns: [sepal length (cm), sepal width (cm), petal length (cm), petal width (cm), cluster]
# Index: []
